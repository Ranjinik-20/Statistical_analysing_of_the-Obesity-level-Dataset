# %%
# Statistic and Trends -  Using a dataset called Obesity dataset various plots as been plotted such as Scatterplot, Histogram, boxplot plot and Heatmap using correlation matrix

# %%
# Importing the required libraries for Plotting

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading the dataset using 'pandas' method and Replacing the term from 'Public_Transportation' to 'PB'

df = pd.read_csv("ObesityDataSet.csv")
df.Transportation = df.Transportation.replace('Public_Transportation', 'PB')
df
# Out:
#             Age  Gender    Height      Weight Consumption of alcohol  \
# 0     21.000000  Female  1.620000   64.000000                     no
# 1     21.000000  Female  1.520000   56.000000              Sometimes
# 2     23.000000    Male  1.800000   77.000000             Frequently
# 3     27.000000    Male  1.800000   87.000000             Frequently
# 4     22.000000    Male  1.780000   89.800000              Sometimes
# ...         ...     ...       ...         ...                    ...
# 2106  20.976842  Female  1.710730  131.408528              Sometimes
# 2107  21.982942  Female  1.748584  133.742943              Sometimes
# 2108  22.524036  Female  1.752206  133.689352              Sometimes
# 2109  24.361936  Female  1.739450  133.346641              Sometimes
# 2110  23.664709  Female  1.738836  133.472641              Sometimes
#
#      Frequent consumption of high caloric food  \
# 0                                           no
# ...

# %%
# Plotting the scatterplot for the Relational Graph, for the columns Age and Weight with Obesity level 

def scatterplot_obesity_level(df):
    '''
    Creates subplots for physical activity according to age and weight.
    '''
    obesity_levels = df['Obesity level'].unique()
    num_levels = len(obesity_levels)
    num_cols = (num_levels + 1) // 2  
    fig, axes = plt.subplots(nrows=2, ncols=num_cols, figsize=(5 * num_cols, 10), sharey=True)
    axes = axes.flatten()
    
    # Iterate through each level to create the subplot
    for i, level in enumerate(obesity_levels):
        subset = df[df['Obesity level'] == level]
        sns.scatterplot(data=subset, x='Age', y='Weight', ax=axes[i], hue='Obesity level', palette='Set2')
        axes[i].set_title(f'Obesity Level: {level}')
        axes[i].set_xlabel('Age')
        axes[i].set_ylabel('Weight')
        axes[i].grid()

    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
scatterplot_obesity_level(df)

# %%
# Plotting the histogram for Categorical graph, for the columns Transportation and Obesity level.

def histogram_obesity(df):
    '''
    Creates subplots for the mode of transport for each obesity level.
    '''
    obesity_levels = df['Obesity level'].unique()
    num_levels = len(obesity_levels)
    num_cols = (num_levels + 1) // 2 
    fig, axes = plt.subplots(nrows=2, ncols=num_cols, figsize=(5 * num_cols, 10), sharey=True)
    axes = axes.flatten()
    
    # Iterate through each to create the subplot
    
    for i, level in enumerate(obesity_levels):
        subset = df[df['Obesity level'] == level]
        axes[i].hist(subset['Transportation'], bins=5, alpha=0.7, edgecolor='black')
        axes[i].set_title(f'Obesity Level: {level}')
        axes[i].set_xlabel('Mode of Transport')
        axes[i].set_ylabel('Count')
        axes[i].grid()
        
    for j in range(i + 1, len(axes)):
        fig.delaxes(axes[j])

    plt.tight_layout()
    plt.show()

# %%
histogram_obesity(df)

# %%
# Plotting the boxplot

def boxplot_obesity(df):
    '''
    Creates an enhanced boxplot to visualize the relationship between high caloric food consumption and physical activity.
    '''
    plt.figure(figsize=(12, 8))
    sns.boxplot(data=df, x='Frequent consumption of high caloric food', y='Frequency of physical activity') 
    plt.title('Relationship Between High Caloric Food Consumption and Physical Activity', fontsize=16)
    plt.xlabel('Frequency of High Caloric Food Consumption', fontsize=14)
    plt.ylabel('Frequency of Physical Activity', fontsize=14)
    plt.xticks(rotation=45)
    plt.yticks(fontsize=12)  
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout() 
    plt.show()

# %%
boxplot_obesity(df)

# %%
# Describing the dataset 

df1 = df
df1.describe()
# Out:
#                Age       Height       Weight  \
# count  2111.000000  2111.000000  2111.000000
# mean     24.312600     1.701677    86.586058
# std       6.345968     0.093305    26.191172
# min      14.000000     1.450000    39.000000
# 25%      19.947192     1.630000    65.473343
# 50%      22.777890     1.700499    83.000000
# 75%      26.000000     1.768464   107.430682
# max      61.000000     1.980000   173.000000
#
#        Frequency of consumption of vegetables  Number of main meals  \
# count                             2111.000000           2111.000000
# mean                                 2.419043              2.685628
# std                                  0.533927              0.778039
# min                                  1.000000              1.000000
# 25%                                  2.000000              2.658738
# 50%                                  2.385502              3.000000
# 75%                                  3.000000              3.000000
# ...

# %%
# Finding the Major moments of the dataset - mean, median, std, skew, kurtosis.

df_num = df1[['Age', 'Height', 'Weight', 'Frequency of consumption of vegetables', 'Number of main meals', 'Consumption of water daily','Frequency of physical activity']]
df_num.agg(['mean', 'median', 'std', 'skew', 'kurtosis'])
# Out:
#                 Age    Height     Weight  \
# mean      24.312600  1.701677  86.586058
# median    22.777890  1.700499  83.000000
# std        6.345968  0.093305  26.191172
# skew       1.529100 -0.012855   0.255410
# kurtosis   2.826389 -0.562949  -0.699898
#
#           Frequency of consumption of vegetables  Number of main meals  \
# mean                                    2.419043              2.685628
# median                                  2.385502              3.000000
# std                                     0.533927              0.778039
# skew                                   -0.432906             -1.107097
# kurtosis                               -0.637546              0.385527
#
#           Consumption of water daily  Frequency of physical activity
# mean                        2.008011                        1.010298
# median                      2.000000                        1.000000
# std                         0.612953                        0.850592
# ...

# %%
# Finding the correlation of the dataset

df_corr = df1.corr(numeric_only = True)
df_corr
# Out:
#                                              Age    Height    Weight  \
# Age                                     1.000000 -0.025958  0.202560
# Height                                 -0.025958  1.000000  0.463136
# Weight                                  0.202560  0.463136  1.000000
# Frequency of consumption of vegetables  0.016291 -0.038121  0.216125
# Number of main meals                   -0.043944  0.243672  0.107469
# Consumption of water daily             -0.045304  0.213376  0.200575
# Frequency of physical activity         -0.144938  0.294709 -0.051436
#
#                                         Frequency of consumption of vegetables  \
# Age                                                                   0.016291
# Height                                                               -0.038121
# Weight                                                                0.216125
# Frequency of consumption of vegetables                                1.000000
# ...

# %%
# Plotting the Correlation Matrix Heatmap for the dataset

def plot_corr(corr):
    plt.figure(figsize=(10, 10))
    sns.set(font_scale=1)
    heatmap = sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8}, linewidths=.5)
    plt.title('Correlation Matrix Heatmap', fontsize=16)
    plt.xticks(rotation=90)
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.show()

# %%
plot_corr(df_corr)
